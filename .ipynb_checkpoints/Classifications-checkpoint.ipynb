# %%
import re
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Sci-Kit Learn
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import cluster, metrics, datasets

# %%
d = pd.read_csv("data/past_seasons_totals.csv", encoding="utf-8")

modern_data = d.loc[(d["Year"]>1980) & (d["G"]>20) & (d["MP"]>200)].fillna("0")
modern_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G',
#        'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%',
#        'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM',
#        'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
#        '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'formatname'],
#       dtype='object')

# %%
X = modern_data[['G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%',
        'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 
        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
        '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
        'STL', 'BLK', 'TOV', 'PF', 'PTS']]
y = modern_data["Pos"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
pca.fit(X_scaled)

X_pca = pca.transform(X_scaled)
print("Cumulative Explained Variance:", pca.explained_variance_ratio_.sum())
# Out:
# Cumulative Explained Variance: 0.6116151024455341

# %%
LDA = LinearDiscriminantAnalysis(n_components=2, shrinkage='auto', solver='eigen')
LDA_reduced_df = LDA.fit(X_scaled,y).transform(X_scaled)
LDA.score(X_scaled,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\shrunk_covariance_.py:193: UserWarning: Only one sample available. You may want to reshape your data array
#   warnings.warn("Only one sample available. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\empirical_covariance_.py:75: UserWarning: Only one sample available. You may want to reshape your data array
#   warnings.warn("Only one sample available. "
# 0.6416800797118112

# %%
def kmeans(reduced_data, n_clusters):
    """
    performs kmeans clustering and returns labels, centroids, inertia, and silhouette score
    """
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans = kmeans.fit(reduced_data)
    labels = kmeans.labels_
    centroids = kmeans.cluster_centers_
    inertia = kmeans.inertia_
    sil_score = metrics.silhouette_score(reduced_data, kmeans.labels_, metric='euclidean')

    data_dictionary = {
        "labels": labels,
        "centroids": centroids,
        "inertia" : inertia,
        "silhouette_score": sil_score
    }

    return data_dictionary

def find_best_cluster(data,a,b):
    """
    plots and finds the best silhouette score for range(a,b)
    """
    scores = []
    for i in range(a,b):
        i_clusters = kmeans(data, i)
        sil_score_i = i_clusters['silhouette_score']
        scores.append(sil_score_i)

    sns.set_context('poster', font_scale=1)
    plt.plot(range(a,b), scores)
    plt.title("""Measuring Silhouette Score to Find Best Cluster""")
    print("best silhouette score:", np.max(scores))
find_best_cluster(LDA_reduced_df,5,20)
# Out:
# best silhouette score: 0.4388878133511681

# %%
kmeans = kmeans(LDA_reduced_df, 20)

# %%
modern_data['Cluster'] = kmeans['labels']
print("silhouette score:", kmeans['silhouette_score'])
# Out:
# silhouette score: 0.32512359465931734

# %%
y = kmeans['labels']
df = pd.DataFrame({'X1':LDA_reduced_df[:,0],'X2':LDA_reduced_df[:,1], 'labels':y})

# %%
def plot_kmeans_cluster(reduced_data, k_clusters, plot_title):
    kmeans = KMeans(init='k-means++', n_clusters=k_clusters, n_init=10)
    kmeans.fit(reduced_data)

    # Step size of the mesh. Decrease to increase the quality of the VQ.
    h = .02     # point in the mesh [x_min, x_max]x[y_min, y_max].

    # Plot the decision boundary. For that, we will assign a color to each
    x_min, x_max = reduced_data[:, 0].min() - 1, reduced_data[:, 0].max() + 1
    y_min, y_max = reduced_data[:, 1].min() - 1, reduced_data[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # Obtain labels for each point in mesh. Use last trained model.
    Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure(1, figsize=(15,10))
    plt.clf()
    plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap=plt.cm.Paired,
           aspect='auto', origin='lower')

    plt.plot(reduced_data[:, 0], reduced_data[:, 1], 'k.', markersize=10)
    # Plot the centroids as a white X
    centroids = kmeans.cluster_centers_
    plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='x', s=169, linewidths=3,
            color='w', zorder=10)
    plt.title(plot_title)
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    plt.xticks(())
    plt.yticks(())
    plt.show()

plot_kmeans_cluster(LDA_reduced_df, k_clusters=20, plot_title="""KMeans""")

# %%
modern_data
# Out:
#        Unnamed: 0  Unnamed: 0.1    Year                           Player Pos  \
# 5053         6085          6085  1981.0             Kareem Abdul-Jabbar*   C
# 5054         6086          6086  1981.0                    Tom Abernethy  SF
# 5055         6089          6089  1981.0                      Alvan Adams   C
# 5056         6090          6090  1981.0                   Darrell Allums  PF
# 5057         6091          6091  1981.0                  Tiny Archibald*  PG
# 5058         6092          6092  1981.0                    Dennis Awtrey   C
# 5059         6093          6093  1981.0                     James Bailey  PF
# 5060         6094          6094  1981.0                     Greg Ballard  SF
# 5061         6095          6095  1981.0                      Mike Bantom  SF
# 5062         6096          6096  1981.0                        Billy Ray  SG
# 5063         6097          6097  1981.0                      Mel Bennett  PF
# 5064         6098          6098  1981.0                      Kent Benson   C
# 5065         6099          6099  1981.0                      Henry Bibby  PG
# 5066         6100          6100  1981.0                      Larry Bird*  PF
# 5067         6101          6101  1981.0                    Otis Birdsong  SG
# 5069         6103          6103  1981.0                        Ron Boone  SG
# 5070         6104          6104  1981.0                   Winford Boynes  SG
# 5071         6105          6105  1981.0                   Dudley Bradley  SG
# 5072         6106          6106  1981.0                       Mike Bratz  PG
# 5073         6107          6107  1981.0                       Jim Brewer  PF
# 5074         6108          6108  1981.0                       Ron Brewer  SG
# 5075         6111          6111  1981.0                 Junior Bridgeman  SF
# 5076         6112          6112  1981.0                    Allan Bristow  SF
# 5078         6114          6114  1981.0                   Michael Brooks  SF
# 5079         6115          6115  1981.0                       Fred Brown  SG
# 5081         6117          6117  1981.0                     Rickey Brown   C
# 5082         6118          6118  1981.0                       Joe Bryant  PF
# 5083         6119          6119  1981.0                    Quinn Buckner  PG
# 5084         6120          6120  1981.0                     Tom Burleson   C
# 5085         6121          6121  1981.0                         Don Buse  SG
# ...           ...           ...     ...                              ...  ..
# 20778         600           600  2018.0          Rashad Vaughn\vaughra01  SG
# 20779         604           604  2018.0            Noah Vonleh\vonleno01  PF
# 20780         607           607  2018.0         Nikola Vucevic\vucevni01   C
# 20781         608           608  2018.0             Dwyane Wade\wadedw01  SG
# 20782         611           611  2018.0           Dion Waiters\waitedi01  SG
# 20783         612           612  2018.0           Kemba Walker\walkeke02  PG
# 20784         613           613  2018.0               John Wall\walljo01  PG
# 20785         614           614  2018.0         Tyrone Wallace\wallaty01  PG
# 20786         615           615  2018.0  Taurean Waller-Prince\princta02  SF
# 20816  25.0  TOR  69.0  1433.0  16.5   ...     153.0  198.0  200.0   72.0
# 20817  22.0  BOS  33.0   235.0  12.3   ...      35.0   52.0   16.0    4.0
# 20819  25.0  IND  53.0   558.0  10.1   ...      51.0   63.0   39.0   14.0
# 20820  32.0  GSW  80.0  1393.0  10.0   ...     105.0  125.0   36.0   38.0
# 20821  29.0  IND  81.0  2607.0  14.8   ...     328.0  512.0  152.0  135.0
# 20822  25.0  CHO  33.0   627.0  15.9   ...     110.0  177.0   31.0   14.0
# 20823  28.0  TOT  66.0  1109.0  16.0   ...     195.0  305.0   47.0   15.0
# 20824  23.0  CHI  54.0   824.0   5.2   ...     118.0  131.0   46.0   20.0
# 20825  21.0  CLE  32.0   214.0  24.2   ...      36.0   60.0    5.0    2.0
# 20826  20.0  LAL  43.0   410.0  15.3   ...      78.0  123.0   25.0    8.0
#
#          BLK    TOV     PF     PTS         formatname  Cluster
# 5053   228.0  249.0  244.0  2095.0  KareemAbdulJabbar        5
# 5054     3.0    8.0   34.0    63.0       TomAbernethy        4
# 5055    69.0  226.0  226.0  1115.0         AlvanAdams       11
# 5056     8.0   23.0   51.0    59.0      DarrellAllums        0
# 5057    18.0  265.0  201.0  1106.0      TinyArchibald       14
# 5058     8.0   33.0   85.0   102.0       DennisAwtrey       11
# 5059   143.0  219.0  332.0  1145.0        JamesBailey       10
# 5060    39.0  117.0  194.0  1271.0        GregBallard        4
# 5061    85.0  197.0  284.0  1061.0         MikeBantom       11
# 5062     6.0  149.0  120.0  1062.0           BillyRay       19
# 5063    11.0   31.0   56.0   105.0         MelBennett        5
# 5064    67.0  190.0  184.0   924.0         KentBenson       11
# 5065     2.0   76.0   85.0   335.0         HenryBibby       16
# 5066    63.0  289.0  239.0  1741.0          LarryBird        8
# 5067    18.0  173.0  172.0  1747.0       OtisBirdsong        2
# 5069     8.0  111.0  126.0   406.0           RonBoone        7
# 5070    16.0   69.0   79.0   287.0      WinfordBoynes       18
# 5071    37.0  122.0  236.0   657.0      DudleyBradley       12
# 5072    17.0  162.0  194.0   802.0          MikeBratz       16
# 5073    58.0   48.0  158.0   217.0          JimBrewer       10
# 5074    34.0   92.0   95.0   642.0          RonBrewer       19
# 5075    28.0  150.0  182.0  1290.0    JuniorBridgeman        6
# 5076     3.0  171.0  190.0   713.0       AllanBristow       17
# 5078    31.0  163.0  234.0  1202.0      MichaelBrooks        4
# 5079    13.0  131.0  141.0  1206.0          FredBrown       19
# 5081    14.0   31.0  103.0   182.0        RickeyBrown        5
# 5082    34.0  176.0  264.0   953.0          JoeBryant        8
# 5083     3.0  236.0  271.0  1092.0       QuinnBuckner       19
# 5084    19.0   24.0   73.0   102.0        TomBurleson        5
# 5085     8.0   38.0   61.0   297.0            DonBuse       19
# ...      ...    ...    ...     ...                ...      ...
# 20778    3.0    6.0   15.0    64.0       RashadVaughn        6
# 20779   17.0   31.0   68.0   264.0         NoahVonleh        5
# 20780   62.0  109.0  144.0   939.0      NikolaVucevic       10
# 20781   47.0  140.0  124.0   765.0         DwyaneWade       17
# 20782    9.0   70.0   61.0   429.0        DionWaiters       19
# 20783   24.0  179.0   98.0  1770.0        KembaWalker       19
# 20784   45.0  158.0   80.0   797.0           JohnWall        1
# 20785   13.0   46.0   83.0   291.0      TyroneWallace       18
# 20786   42.0  191.0  168.0  1158.0      TaureanPrince       18
# 20789   41.0   85.0  149.0  1271.0           TJWarren        4
# 20793   75.0   80.0  120.0   495.0          DavidWest       11
# 20794   20.0  381.0  200.0  2028.0   RussellWestbrook       17
# 20799   94.0   92.0  131.0   754.0    HassanWhiteside        3
# 20800   51.0  138.0  163.0  1452.0      AndrewWiggins       15
# 20804   13.0   20.0   63.0   209.0         CJWilliams        2
# 20806   19.0  234.0  106.0  1782.0        LouWilliams       19
# 20807   38.0   66.0  116.0   744.0     MarvinWilliams        4
# 20809    4.0   19.0   34.0   133.0       TroyWilliams       15
# 20812   33.0   77.0  140.0   529.0     JustiseWinslow       11
# 20815   26.0    8.0   32.0   139.0      BrandanWright        5
# 20816   33.0   78.0   81.0   555.0        DelonWright       17
# 20817    5.0   12.0   23.0    79.0  GuerschonYabusele        8
# 20819    1.0   26.0   39.0   207.0        JosephYoung        6
# 20820    7.0   40.0  100.0   581.0          NickYoung        2
# 20821   36.0  105.0  175.0   955.0      ThaddeusYoung       15
# 20822   21.0   33.0   81.0   233.0         CodyZeller       10
# 20823   35.0   47.0  126.0   441.0        TylerZeller        5
# 20824   15.0   43.0   86.0   218.0         PaulZipser       18
# 20825   13.0   11.0   30.0   119.0          AnteZizic       13
# 20826   15.0   26.0   47.0   161.0         IvicaZubac        5
#
# [13047 rows x 53 columns]

# %%
def feature_importance(cluster_data, league_data):
    """
    takes reduced data,
    performs Principal Component Analysis,
    returns feature importance dataframe
    """
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(cluster_data)

    pca = PCA(n_components=2)
    PCA_reduced_df = pca.fit(scaled_data).transform(scaled_data)

    features = pd.DataFrame(zip(cluster_data.columns, pca.components_[0], np.mean(cluster_data), np.mean(league_data)),
        columns=['Feature', 'Importance', 'Cluster Average', 'League Average']).sort_values('Importance', ascending=False).head(10)

    return features

# %%
for i in range(0,20):
    mask = (modern_data['Cluster'] == i)
    print(modern_data[mask][['Player']].head())
# Out:
#                Player
# 5056   Darrell Allums
# 5094  Bill Cartwright
# 5133       Len Elmore
# 5137    Eric Fernsten
# 5145       Gus Gerard
#                Player
# 5140        Phil Ford
# 5221    Allen Leavell
# 5226       John Lucas
# 5293       John Roche
# 5360  Tiny Archibald*
#                 Player
# 5067     Otis Birdsong
# 5153      Kevin Grevey
# 5155  Darrell Griffith
# 5169      Keith Herron
# 5225         John Long
#                 Player
# 5095  Harvey Catchings
# 5185    George Johnson
# 5254        Swen Nater
# 5266    Robert Parish*
# 5490    George Johnson
#               Player
# 5054   Tom Abernethy
# 5060    Greg Ballard
# 5078  Michael Brooks
# 5124       John Drew
# 5129       T.R. Dunn
#                     Player
# 5053  Kareem Abdul-Jabbar*
# 5063           Mel Bennett
# 5081          Rickey Brown
# 5084          Tom Burleson
# 5089            Kenny Carr
#                 Player
# 5075  Junior Bridgeman
# 5088       Austin Carr
# 5092      Butch Carter
# 5099       Art Collins
# 5100       Don Collins
#              Player
# 5069      Ron Boone
# 5128  Mike Dunleavy
# 5130     John Duren
# 5136     Mike Evans
# 5172    Armond Hill
#                Player
# 5066      Larry Bird*
# 5082       Joe Bryant
# 5150  Glen Gondrezick
# 5162      Mike Harper
# 5166        Gar Heard
#             Player
# 5275  Kevin Porter
# 5331  Lloyd Walton
# 5534    John Lucas
# 5559  Johnny Moore
# 5839    John Lucas
#             Player
# 5059  James Bailey
# 5073    Jim Brewer
# 5109  Pat Cummings
# 5110  Earl Cureton
# 5119   Larry Demic
#              Player
# 5055    Alvan Adams
# 5058  Dennis Awtrey
# 5061    Mike Bantom
# 5064    Kent Benson
# 5103      Jeff Cook
#               Player
# 5071  Dudley Bradley
# 5127    Terry Duerod
# 5138      Chris Ford
# 5148      Mike Glenn
# 5163     Joe Hassett
#                Player
# 5105     Wayne Cooper
# 5118   Darryl Dawkins
# 5121  James Donaldson
# 5147   Artis Gilmore*
# 5212    Kevin Kunnert
#                Player
# 5057  Tiny Archibald*
# 5096   Maurice Cheeks
# 5113       Brad Davis
# 5168    Tom Henderson
# 5170      Kenny Higgs
#                Player
# 5112  Adrian Dantley*
# 5116        Ron Davis
# 5209     Billy Knight
# 5267     Sonny Parker
# 5272    Roger Phegley
#              Player
# 5065    Henry Bibby
# 5072     Mike Bratz
# 5107  Charlie Criss
# 5114   Johnny Davis
# 5125     Larry Drew
#               Player
# 5076   Allan Bristow
# 5093   Reggie Carter
# 5157  Ernie Grunfeld
# 5188  Magic Johnson*
# 5206      Chad Kinch
#               Player
# 5070  Winford Boynes
# 5086    Marty Byrnes
# 5090       M.L. Carr
# 5111   Bob Dandridge
# 5146  George Gervin*
#              Player
# 5062      Billy Ray
# 5074     Ron Brewer
# 5079     Fred Brown
# 5083  Quinn Buckner
# 5085       Don Buse

# %%
cluster_data = modern_data[mask][['G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%',
        'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 
        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
        '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
        'STL', 'BLK', 'TOV', 'PF', 'PTS']]
league_data = modern_data[['G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%',
        'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 
        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
        '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
        'STL', 'BLK', 'TOV', 'PF', 'PTS']]

scaler = StandardScaler()
scaled_data = scaler.fit_transform(cluster_data)

pca = PCA(n_components=2)
PCA_reduced_df = pca.fit(scaled_data).transform(scaled_data)

npmc = np.mean(cluster_data)
npml = np.mean(league_data)

features = pd.DataFrame(list(zip(cluster_data.columns, pca.components_[0], npmc, npml)), columns=['Feature', 'Importance', 'Cluster Average', 'League Average']).sort_values('Importance', ascending=False)#.head(10)
features
# Out:
#    Feature  Importance  Cluster Average  League Average
# 38     AST    0.205965       219.874336       32.453897
# 22      FG    0.202752       272.785841      248.063769
# 37     TRB    0.202387       151.895575       51.551928
# 20189  20.0  LAL  63.0  1811.0  15.3   ...     191.0  222.0  303.0   87.0
# 20205  22.0  BOS  79.0  2399.0  12.0   ...     228.0  306.0  364.0  125.0
# 20251  26.0  CHO  79.0  2739.0  21.3   ...     263.0  308.0  435.0   85.0
# 20255  32.0  ORL  62.0  1012.0   9.3   ...      73.0   89.0  114.0   43.0
# 20267  30.0  TOT  81.0  1994.0  21.4   ...     176.0  202.0  239.0   80.0
# 20277  24.0  TOR  27.0   446.0  15.0   ...      32.0   48.0   57.0   27.0
# 20305  23.0  CHI  24.0   304.0   7.3   ...      24.0   25.0   35.0   13.0
# 20313  24.0  NYK  29.0   385.0   9.3   ...      25.0   30.0   47.0   26.0
# 20338  28.0  TOT  74.0  2322.0  19.7   ...     233.0  284.0  370.0  149.0
# 20366  28.0  DET  29.0   427.0  12.8   ...      29.0   41.0   59.0   19.0
# 20384  25.0  TOT  81.0  1888.0  16.4   ...     160.0  217.0  221.0   58.0
# 20402  37.0  MIN  80.0  1653.0  13.0   ...      78.0   99.0  185.0   40.0
# 20406  29.0  GSW  51.0  1631.0  28.2   ...     225.0  261.0  310.0   80.0
# 20525  25.0  BOS  60.0  1931.0  25.0   ...     194.0  227.0  306.0   65.0
# 20584  27.0  POR  73.0  2670.0  25.2   ...     263.0  325.0  481.0   77.0
# 20626  29.0  SAS  82.0  2107.0  11.8   ...     128.0  154.0  229.0   55.0
# 20631  19.0  CHO  63.0   854.0  10.3   ...      58.0   66.0   91.0   20.0
# 20714  25.0  LAC  61.0  2057.0  12.6   ...     118.0  145.0  242.0   74.0
# 20731  23.0  MEM  35.0   692.0  11.8   ...      40.0   56.0   66.0   18.0
# 20741  20.0  DAL  69.0  2049.0  12.8   ...     210.0  260.0  358.0   71.0
# 20761  40.0  MIL  51.0   814.0   8.1   ...      43.0   48.0   59.0   42.0
# 20782  26.0  MIA  30.0   918.0  10.5   ...      69.0   77.0  113.0   23.0
# 20783  27.0  CHO  80.0  2736.0  20.6   ...     216.0  247.0  444.0   91.0
# 20806  31.0  LAC  79.0  2589.0  20.2   ...     158.0  198.0  417.0   85.0
#
#         BLK    TOV     PF     PTS       formatname  Cluster
# 12178   3.0   75.0  150.0   491.0      DerekFisher       19
# 12233  22.0  145.0  216.0  1043.0    LindseyHunter       19
# 12245   4.0   32.0   58.0   154.0   AnthonyJohnson       19
# 12268  28.0  146.0  112.0   830.0        ToniKukoc       19
# 12371   9.0  100.0   79.0   641.0      TerryPorter       19
# 12499   3.0   43.0   63.0   282.0      GregAnthony       19
# 12508   2.0   60.0   63.0   478.0       DanaBarros       19
# 12509  14.0   86.0  126.0   589.0       BrentBarry       19
# 12510   6.0   53.0   66.0   316.0         JonBarry       19
# 12600  12.0  102.0  218.0   741.0     HowardEisley       19
# 12656   9.0   19.0   45.0   183.0    HerseyHawkins       19
# 12665   0.0   35.0   58.0   251.0       EddieHouse       19
# 12670  12.0   68.0  172.0   825.0    LindseyHunter       19
# 12694   1.0   21.0   30.0   181.0        SteveKerr       19
# 12714   0.0   27.0   54.0   130.0        TyronnLue       19
# 12723   5.0   70.0   94.0   369.0      MattMaloney       19
# 12744   8.0  203.0  178.0   878.0       AaronMcKie       19
# 12800   2.0   34.0   57.0   267.0    MikePenberthy       19
# 12908  16.0  171.0  220.0  1414.0      DavidWesley       19
# 12937   8.0   87.0  113.0   757.0    DerekAnderson       19
# 12946  11.0  128.0  177.0   957.0     ChuckyAtkins       19
# 12949   0.0   19.0   17.0    71.0     WilliamAvery       19
# 12963  15.0  134.0  133.0  1098.0        MikeBibby       19
# 13011   6.0   95.0  145.0   480.0    SpeedyClaxton       19
# 13057   9.0   62.0  121.0   786.0      DerekFisher       19
# 13110   5.0   80.0   98.0   514.0       EddieHouse       19
# 13114  23.0  171.0  150.0   895.0      LarryHughes       19
# 13118  13.0  237.0  102.0  1883.0     AllenIverson       19
# 13239   4.0   40.0   61.0   231.0      MiltPalacio       19
# 13302   7.0   62.0   76.0   321.0      WillSolomon       19
# ...     ...    ...    ...     ...              ...      ...
# 19954  16.0   96.0  119.0   517.0     ManuGinobili       19
# 19962   8.0   44.0   93.0   370.0      JerianGrant       19
# 20074  19.0  173.0  170.0  1344.0        KyleLowry       19
# 20078   3.0   90.0  100.0   430.0      ShelvinMack       19
# 20121   2.0   41.0   38.0   218.0    ShabazzNapier       19
# 20125   5.0   15.0   48.0   100.0         RaulNeto       19
# 20189  16.0  176.0  130.0   984.0   DAngeloRussell       19
# 20205  34.0  159.0  192.0   835.0      MarcusSmart       19
# 20251  22.0  168.0  119.0  1830.0      KembaWalker       19
# 20255   2.0   47.0   84.0   281.0         CJWatson       19
# 20267  19.0  160.0   92.0  1421.0      LouWilliams       19
# 20277  11.0   25.0   31.0   150.0      DelonWright       19
# 20305   0.0   13.0   18.0    48.0  RyanArcidiacono       19
# 20313   6.0   18.0   33.0    71.0         RonBaker       19
# 20338  42.0  216.0  185.0  1313.0      EricBledsoe       19
# 20366   2.0   39.0   39.0   215.0     DwightBuycks       19
# 20384   6.0  127.0  107.0  1124.0   JordanClarkson       19
# 20402   9.0   95.0   85.0   822.0    JamalCrawford       19
# 20406   8.0  153.0  114.0  1346.0     StephenCurry       19
# 20525  17.0  140.0  122.0  1466.0      KyrieIrving       19
# 20584  27.0  206.0  117.0  1962.0    DamianLillard       19
# 20626  11.0  106.0  128.0   819.0     PatrickMills       19
# 20631   9.0   48.0   59.0   421.0        MalikMonk       19
# 20714  16.0  109.0  152.0   920.0     AustinRivers       19
# 20731   5.0   54.0   59.0   325.0      WayneSelden       19
# 20741  18.0  195.0  152.0  1048.0      DennisSmith       19
# 20761  13.0   25.0   52.0   166.0       JasonTerry       19
# 20782   9.0   70.0   61.0   429.0      DionWaiters       19
# 20783  24.0  179.0   98.0  1770.0      KembaWalker       19
# 20806  19.0  234.0  106.0  1782.0      LouWilliams       19
#
# [320 rows x 53 columns]
