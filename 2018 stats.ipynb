# %%
import pandas as pd

import json

tot2018 = pd.read_csv("data/tot_stats_2018.csv", encoding="utf-8")
adv2018 = pd.read_csv("data/adv_stats_2018.csv", encoding="utf-8")

# %%
for i in range(0,len(tot2018)):
    tot2018["format_name"].iloc[i]=str(tot2018["Player"].iloc[i]).split("\\",1)[0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
for i in range(0,len(adv2018)):
    adv2018["format_name"].iloc[i]=str(adv2018["Player"].iloc[i]).split("\\",1)[0]
adv2018
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#       Rk                           Player Pos  Age   Tm   G    MP   PER  \
# 0      1           Alex Abrines\abrinal01  SG   24  OKC  75  1134   9.0
# 1      2               Quincy Acy\acyqu01  PF   27  BRK  70  1359   8.2
# 2      3           Steven Adams\adamsst01   C   24  OKC  76  2487  20.6
# 3      4            Bam Adebayo\adebaba01   C   20  MIA  69  1368  15.7
# 4      5          Arron Afflalo\afflaar01  SG   32  ORL  53   682   5.8
# 5      6           Cole Aldrich\aldrico01   C   29  MIN  21    49   6.0
# 6      7      LaMarcus Aldridge\aldrila01   C   32  SAS  75  2509  25.0
# 7      8          Jarrett Allen\allenja01   C   19  BRK  72  1441  17.5
# 8      9           Kadeem Allen\allenka01  PG   25  BOS  18   107   2.6
# 9     10             Tony Allen\allento01  SF   36  NOP  22   273   8.7
# 10    11        Al-Farouq Aminu\aminual01  PF   27  POR  69  2072  12.0
# 11    12        Justin Anderson\anderju01  SF   24  PHI  38   519  13.0
# 12    13          Kyle Anderson\anderky01  SF   24  SAS  74  1978  15.9
# 13    14          Ryan Anderson\anderry01  PF   29  HOU  66  1725  12.6
# 14    15           Ike Anigbogu\anigbik01   C   19  IND  11    30  21.6
# 15    16  Giannis Antetokounmpo\antetgi01  PF   23  MIL  75  2756  27.3
# 16    17        Carmelo Anthony\anthoca01  PF   33  OKC  78  2501  12.7
# 17    18             OG Anunoby\anunoog01  SF   20  TOR  74  1481  10.0
# 18    19       Ryan Arcidiacono\arcidry01  PG   23  CHI  24   304   7.3
# 19    20           Trevor Ariza\arizatr01  SF   32  HOU  67  2269  11.8
# 20    21         Darrell Arthur\arthuda01  PF   29  DEN  19   141   8.4
# 21    22            Jamel Artis\artisja01  SG   25  ORL  15   279   6.9
# 22    23               Omer Asik\asikom01   C   31  TOT  18   182   3.1
# 23    23               Omer Asik\asikom01   C   31  NOP  14   121   4.5
# 24    23               Omer Asik\asikom01   C   31  CHI   4    61   0.2
# 25    24          D.J. Augustin\augusdj01  PG   30  ORL  75  1760  15.4
# 26    25           Luke Babbitt\babbilu01  SF   28  TOT  50   715   9.8
# 27    25           Luke Babbitt\babbilu01  SF   28  ATL  37   570  12.0
# 28    25           Luke Babbitt\babbilu01  SF   28  MIA  13   145   1.3
# 29    26           Dwayne Bacon\bacondw01  SG   22  CHO  53   713   5.8
# ..   ...                              ...  ..  ...  ...  ..   ...   ...
# 634  517          Alan Williams\willial03  PF   25  PHO   5    70   9.3
# 635  518          C.J. Williams\willicj01  SG   27  LAC  38   707   9.5
# 636  519       Derrick Williams\willide02  PF   26  LAL   2     9  -3.2
# 637  520           Lou Williams\willilo02  SG   31  LAC  79  2589  20.2
# 638  521        Marvin Williams\willima02  PF   31  CHO  78  2006  13.9
# 639  522          Matt Williams\willima05  SG   24  MIA   3    11  -0.7
# 640  523          Troy Williams\willitr02  SF   23  TOT  21   307  15.1
# 641  523          Troy Williams\willitr02  SF   23  HOU   4    17  -2.4
# 642  523          Troy Williams\willitr02  SF   23  NYK  17   290  16.2
# 643  524            D.J. Wilson\wilsodj01  PF   21  MIL  22    71  10.3
# 644  525           Jamil Wilson\wilsoja02  SF   27  LAC  15   274  11.4
# 645  526        Justise Winslow\winslju01  PF   21  MIA  68  1680  11.5
# 646  527            Jeff Withey\witheje01   C   27  DAL   9    39   8.3
# 647  528           Nate Wolters\woltena01  PG   26  UTA   5    19  -2.9
# 648  529         Brandan Wright\wrighbr03  PF   30  TOT  28   381  19.0
# 649  529         Brandan Wright\wrighbr03  PF   30  MEM  27   366  19.3
# 650  529         Brandan Wright\wrighbr03  PF   30  HOU   1    15  11.3
# 651  530           Delon Wright\wrighde01  PG   25  TOR  69  1433  16.5
# 652  531     Guerschon Yabusele\yabusgu01  PF   22  BOS  33   235  12.3
# 653  532            James Young\youngja01  SG   22  PHI   6    61   4.6
# 654  533              Joe Young\youngjo01  PG   25  IND  53   558  10.1
# 655  534             Nick Young\youngni01  SG   32  GSW  80  1393  10.0
# 656  535         Thaddeus Young\youngth01  PF   29  IND  81  2607  14.8
# 657  536            Cody Zeller\zelleco01   C   25  CHO  33   627  15.9
# 658  537           Tyler Zeller\zellety01   C   28  TOT  66  1109  16.0
# 659  537           Tyler Zeller\zellety01   C   28  BRK  42   703  15.3
# 660  537           Tyler Zeller\zellety01   C   28  MIL  24   406  17.1
# 661  538            Paul Zipser\zipsepa01  SF   23  CHI  54   824   5.2
# 662  539             Ante Zizic\zizican01   C   21  CLE  32   214  24.2
# 663  540            Ivica Zubac\zubaciv01   C   20  LAL  43   410  15.3
#
#        TS%   3PAr          ...            USG%  OWS  DWS    WS  WS/48  OBPM  \
# 0    0.567  0.759          ...            12.7  1.3  1.0   2.2  0.094  -0.5
# 1    0.525  0.800          ...            14.4 -0.1  1.1   1.0  0.036  -2.0
# 2    0.630  0.003          ...            16.7  6.7  3.0   9.7  0.187   2.2
# 3    0.570  0.021          ...            15.9  2.3  1.9   4.2  0.148  -1.6
# 4    0.516  0.432          ...            12.5 -0.1  0.2   0.1  0.009  -4.1
# 5    0.340  0.000          ...            16.8 -0.1  0.1   0.0 -0.013  -7.0
# 6    0.570  0.068          ...            29.1  7.4  3.5  10.9  0.209   3.0
# 7    0.636  0.038          ...            16.3  2.7  1.5   4.2  0.141  -1.3
# 8    0.366  0.500          ...            14.6 -0.2  0.1  -0.1 -0.039  -6.7
# 9    0.514  0.132          ...            18.9 -0.2  0.2   0.1  0.017  -4.0
# 10   0.522  0.582          ...            14.8  0.9  3.2   4.2  0.097  -0.8
# 11   0.540  0.510          ...            19.3  0.6  0.7   1.2  0.115  -0.5
# 12   0.582  0.130          ...            13.5  2.4  3.8   6.2  0.151  -0.3
# 13   0.592  0.706          ...            14.4  3.1  1.7   4.8  0.132   1.0
# 14   0.558  0.000          ...            20.3  0.1  0.0   0.1  0.165  -4.1
# 15   0.598  0.100          ...            31.2  8.3  3.6  11.9  0.207   3.9
# 16   0.503  0.406          ...            23.2  1.2  2.5   3.7  0.071  -1.9
# 17   0.587  0.569          ...            12.4  1.4  1.6   3.0  0.098   0.2
# 18   0.550  0.756          ...             8.1  0.1  0.2   0.3  0.040  -3.3
# 19   0.567  0.710          ...            14.4  2.6  2.8   5.3  0.113   0.8
# 20   0.559  0.489          ...            19.5 -0.2  0.1   0.0 -0.011  -3.5
# 21   0.457  0.367          ...            14.5 -0.1  0.1   0.0 -0.006  -4.3
# 22   0.397  0.000          ...             8.7 -0.2  0.2  -0.1 -0.021  -8.1
# 23   0.423  0.000          ...             9.4 -0.1  0.1   0.0  0.008  -7.4
# 24   0.311  0.000          ...             7.4 -0.1  0.0  -0.1 -0.077  -9.6
# 25   0.615  0.504          ...            18.6  3.3  0.8   4.1  0.110   1.5
# 26   0.576  0.726          ...            15.0  0.5  0.4   0.9  0.060  -1.0
# 27   0.636  0.661          ...            14.8  0.9  0.3   1.1  0.094   0.1
# 28   0.351  0.957          ...            15.8 -0.3  0.1  -0.2 -0.073  -5.2
# 29   0.431  0.224          ...            13.7 -0.7  0.6  -0.1 -0.007  -5.4
# ..     ...    ...          ...             ...  ...  ...   ...    ...   ...
# 634  0.455  0.000          ...            17.5 -0.1  0.1   0.0 -0.004  -6.5
# 635  0.512  0.396          ...            13.7  0.3  0.5   0.7  0.051  -1.3
# 636  0.250  0.500          ...            18.9  0.0  0.0   0.0 -0.191 -11.5
# 637  0.574  0.387          ...            29.8  5.5  1.2   6.7  0.125   3.8
# 638  0.603  0.542          ...            14.8  3.1  1.9   5.0  0.119   1.1
# 639  0.417  0.833          ...            28.6 -0.1  0.0   0.0 -0.197  -8.5
# 640  0.544  0.349          ...            20.1  0.2  0.4   0.5  0.085  -0.1
# 641  0.242  0.556          ...            29.4 -0.1  0.0  -0.1 -0.260 -11.6
# 642  0.572  0.330          ...            19.5  0.3  0.3   0.6  0.105   0.6
# 643  0.622  0.313          ...            13.3  0.0  0.1   0.1  0.054  -2.9
# 644  0.634  0.778          ...            14.3  0.4  0.2   0.5  0.096   1.1
# 645  0.496  0.264          ...            16.3  0.2  2.4   2.6  0.075  -2.7
# 646  0.444  0.625          ...            22.0 -0.1  0.1   0.0 -0.054  -9.1
# 647  0.167  0.000          ...            14.2 -0.1  0.0  -0.1 -0.137 -10.3
# 648  0.596  0.000          ...            14.7  0.8  0.5   1.3  0.163  -1.3
# 649  0.595  0.000          ...            14.9  0.8  0.5   1.2  0.163  -1.2
# 650  0.667  0.000          ...             8.8  0.0  0.0   0.0  0.157  -2.5
# 651  0.574  0.354          ...            17.2  2.5  2.1   4.5  0.152   1.2
# 652  0.559  0.607          ...            15.7  0.3  0.3   0.6  0.122  -1.0
# 653  0.511  0.714          ...            12.3  0.0  0.0   0.1  0.041  -3.0
# 654  0.521  0.355          ...            18.0  0.1  0.4   0.5  0.043  -2.4
# 655  0.562  0.668          ...            17.6  0.8  0.9   1.7  0.058  -0.2
# 656  0.528  0.209          ...            17.3  2.3  3.2   5.5  0.101   0.1
# 657  0.602  0.019          ...            15.7  1.2  0.7   1.9  0.145  -0.6
# 658  0.598  0.084          ...            16.4  2.0  0.9   2.9  0.126  -1.1
# 659  0.587  0.114          ...            17.9  1.0  0.6   1.5  0.105  -1.9
# 660  0.622  0.019          ...            13.9  1.1  0.3   1.4  0.163   0.3
# 661  0.444  0.470          ...            15.2 -1.2  0.6  -0.6 -0.034  -5.5
# 662  0.746  0.000          ...            18.8  0.9  0.2   1.0  0.231   1.3
# 663  0.557  0.008          ...            17.6  0.5  0.5   1.0  0.118  -2.7
#
#      DBPM   BPM  VORP            format_name
# 0    -1.7  -2.2  -0.1           Alex Abrines
# 1    -0.2  -2.2  -0.1             Quincy Acy
# 2     1.1   3.3   3.3           Steven Adams
# 3     1.8   0.2   0.8            Bam Adebayo
# 4    -1.8  -5.8  -0.7          Arron Afflalo
# 5     0.1  -6.9  -0.1           Cole Aldrich
# 6     0.3   3.3   3.3      LaMarcus Aldridge
# 7     1.4   0.2   0.8          Jarrett Allen
# 8     0.3  -6.4  -0.1           Kadeem Allen
# 9    -1.3  -5.2  -0.2             Tony Allen
# 10    1.9   1.1   1.6        Al-Farouq Aminu
# 11   -1.5  -2.0   0.0        Justin Anderson
# 12    4.3   4.1   3.0          Kyle Anderson
# 13   -0.8   0.2   1.0          Ryan Anderson
# 14   -1.2  -5.4   0.0           Ike Anigbogu
# 15    1.9   5.8   5.4  Giannis Antetokounmpo
# 16   -1.9  -3.8  -1.1        Carmelo Anthony
# 17    0.4   0.6   1.0             OG Anunoby
# 18   -0.7  -4.1  -0.2       Ryan Arcidiacono
# 19    0.7   1.5   2.0           Trevor Ariza
# 20   -1.0  -4.5  -0.1         Darrell Arthur
# 21   -1.5  -5.9  -0.3            Jamel Artis
# 22    0.0  -8.1  -0.3              Omer Asik
# 23   -0.7  -8.1  -0.2              Omer Asik
# 24    1.6  -8.0  -0.1              Omer Asik
# 25   -2.5  -0.9   0.5          D.J. Augustin
# 26   -2.2  -3.2  -0.2           Luke Babbitt
# 27   -2.1  -2.0   0.0           Luke Babbitt
# 28   -2.7  -7.9  -0.2           Luke Babbitt
# 29   -0.3  -5.7  -0.7           Dwayne Bacon
# ..    ...   ...   ...                    ...
# 634   2.8  -3.7   0.0          Alan Williams
# 635  -0.1  -1.4   0.1          C.J. Williams
# 636  -6.6 -18.1   0.0       Derrick Williams
# 637  -2.9   1.0   2.0           Lou Williams
# 638   0.5   1.7   1.9        Marvin Williams
# 639  -8.6 -17.1   0.0          Matt Williams
# 640   0.2   0.0   0.2          Troy Williams
# 641  -2.6 -14.2  -0.1          Troy Williams
# 642   0.3   0.9   0.2          Troy Williams
# 643  -1.2  -4.1   0.0            D.J. Wilson
# 644  -1.1   0.0   0.1           Jamil Wilson
# 645   1.7  -1.0   0.4        Justise Winslow
# 646  -3.7 -12.8  -0.1            Jeff Withey
# 647  -2.1 -12.4   0.0           Nate Wolters
# 648   2.2   0.9   0.3         Brandan Wright
# 649   2.3   1.1   0.3         Brandan Wright
# 650  -0.6  -3.2   0.0         Brandan Wright
# 651   1.6   2.8   1.7           Delon Wright
# 652   0.2  -0.7   0.1     Guerschon Yabusele
# 653  -3.6  -6.6  -0.1            James Young
# 654  -2.3  -4.7  -0.4              Joe Young
# 655  -3.4  -3.7  -0.6             Nick Young
# 656   1.4   1.5   2.3         Thaddeus Young
# 657   1.3   0.7   0.4            Cody Zeller
# 658  -0.5  -1.6   0.1           Tyler Zeller
# 659  -0.6  -2.5  -0.1           Tyler Zeller
# 660  -0.4  -0.1   0.2           Tyler Zeller
# 661  -0.3  -5.9  -0.8            Paul Zipser
# 662  -1.2   0.1   0.1             Ante Zizic
# 663   0.5  -2.2   0.0            Ivica Zubac
#
# [664 rows x 28 columns]

# %%
adv_tot_2018 = pd.merge(adv2018,tot2018,how="inner",on=["format_name","Tm"])
the_df = adv_tot_2018.drop_duplicates(["format_name"])

# %%
player_list = sorted(set(the_df["format_name"].astype(str)))

# %%
player_list
# Out:
# ['Aaron Brooks',
#  'Aaron Gordon',
#  'Aaron Harrison',
#  'Aaron Jackson',
#  'Abdel Nader',
#  'Adreian Payne',
#  'Al Horford',
#  'Al Jefferson',
#  'Al-Farouq Aminu',
#  'Alan Williams',
#  'Alec Burks',
#  'Alec Peters',
#  'Alex Abrines',
#  'Alex Caruso',
#  'Alex Len',
#  'Alex Poythress',
#  'Alfonzo McKinnie',
#  'Allen Crabbe',
#  'Amir Johnson',
#  'Andre Drummond',
#  'Andre Iguodala',
#  'Andre Ingram',
#  'Andre Roberson',
#  'Andrew Bogut',
#  'Andrew Harrison',
#  'Andrew White',
#  'Andrew Wiggins',
#  'Ante Zizic',
#  'Anthony Brown',
#  'Anthony Davis',
#  'Anthony Tolliver',
#  'Antonio Blakeney',
#  'Antonius Cleveland',
#  'Aron Baynes',
#  'Arron Afflalo',
#  'Austin Rivers',
#  'Avery Bradley',
#  'Bam Adebayo',
#  'Ben McLemore',
#  'Ben Moore',
#  'Ben Simmons',
#  'Bismack Biyombo',
#  'Blake Griffin',
#  'Boban Marjanovic',
#  'Bobby Brown',
#  'Bobby Portis',
#  'Bogdan Bogdanovic',
#  'Bojan Bogdanovic',
#  'Bradley Beal',
#  'Brandan Wright',
#  'Brandon Ingram',
#  'Brandon Jennings',
#  'Brandon Paul',
#  'Briante Weber',
#  'Brice Johnson',
#  'Brook Lopez',
#  'Bruno Caboclo',
#  'Bryn Forbes',
#  'Buddy Hield',
#  'C.J. Miles',
#  'C.J. Williams',
#  'CJ McCollum',
#  'Caleb Swanigan',
#  'Cameron Payne',
#  'Caris LeVert',
#  'Carmelo Anthony',
#  'Cedi Osman',
#  'Chandler Parsons',
#  'Channing Frye',
#  'Charles Cooke',
#  'Cheick Diallo',
#  'Chinanu Onuaku',
#  'Chris Boucher',
#  'Chris McCullough',
#  'Chris Paul',
#  'Clint Capela',
#  'Cody Zeller',
#  'Cole Aldrich',
#  'Corey Brewer',
#  'Cory Joseph',
#  'Courtney Lee',
#  'Cristiano Felicio',
#  "D'Angelo Russell",
#  'D.J. Augustin',
#  'D.J. Wilson',
#  'Dakari Johnson',
#  'Damian Jones',
#  'Damian Lillard',
#  'Damien Wilkins',
#  'Damion Lee',
#  'Damyean Dotson',
#  'Daniel Hamilton',
#  'Daniel Theis',
#  'Danilo Gallinari',
#  'Danny Green',
#  'Dante Cunningham',
#  'Dante Exum',
#  'Danuel House',
#  'Dario Saric',
#  'Darius Miller',
#  'Darrell Arthur',
#  'Darren Collison',
#  'Darrun Hilliard',
#  'David Nwaba',
#  'David Stockton',
#  'David West',
#  'Davis Bertans',
#  'Davon Reed',
#  "De'Aaron Fox",
#  'DeAndre Jordan',
#  'DeAndre Liggins',
#  "DeAndre' Bembry",
#  'DeMar DeRozan',
#  'DeMarcus Cousins',
#  'DeMarre Carroll',
#  'Dejounte Murray',
#  'Delon Wright',
#  'Demetrius Jackson',
#  'Dennis Schroder',
#  'Dennis Smith',
#  'Denzel Valentine',
#  'Derrick Favors',
#  'Derrick Jones',
#  'Derrick Rose',
#  'Derrick Walton',
#  'Derrick White',
#  'Derrick Williams',
#  'Devin Booker',
#  'Devin Harris',
#  'Devin Robinson',
#  'Dewayne Dedmon',
#  'Deyonta Davis',
#  'Dillon Brooks',
#  'Dion Waiters',
#  'Dirk Nowitzki',
#  'Domantas Sabonis',
#  'Donovan Mitchell',
#  'Dorian Finney-Smith',
#  'Doug McDermott',
#  'Dragan Bender',
#  'Draymond Green',
#  'Dwayne Bacon',
#  'Dwight Buycks',
#  'Dwight Howard',
#  'Dwight Powell',
#  'Dwyane Wade',
#  "E'Twaun Moore",
#  'Ed Davis',
#  'Edmond Sumner',
#  'Ekpe Udoh',
#  'Elfrid Payton',
#  'Emeka Okafor',
#  'Emmanuel Mudiay',
#  'Enes Kanter',
#  'Eric Bledsoe',
#  'Eric Gordon',
#  'Eric Moreland',
#  'Erik McCree',
#  'Ersan Ilyasova',
#  'Evan Fournier',
#  'Evan Turner',
#  'Frank Kaminsky',
#  'Frank Mason',
#  'Frank Ntilikina',
#  'Fred VanVleet',
#  'Furkan Korkmaz',
#  'Garrett Temple',
#  'Gary Harris',
#  'Gary Payton',
#  'George Hill',
#  'Georges Niang',
#  'Georgios Papagiannis',
#  'Gerald Green',
#  'Gian Clavell',
#  'Giannis Antetokounmpo',
#  'Glenn Robinson',
#  'Goran Dragic',
#  'Gordon Hayward',
#  'Gorgui Dieng',
#  'Greg Monroe',
#  'Guerschon Yabusele',
#  'Harrison Barnes',
#  'Hassan Whiteside',
#  'Henry Ellenson',
#  'Ian Clark',
#  'Ian Mahinmi',
#  'Ike Anigbogu',
#  'Iman Shumpert',
#  'Isaiah Canaan',
#  'Isaiah Hicks',
#  'Isaiah Taylor',
#  'Isaiah Thomas',
#  'Isaiah Whitehead',
#  'Ish Smith',
#  'Ivan Rabb',
#  'Ivica Zubac',
#  'J.J. Barea',
#  'J.J. Redick',
#  'J.R. Smith',
#  'JaKarr Sampson',
#  'JaMychal Green',
#  'JaVale McGee',
#  'Jabari Bird',
#  'Jabari Parker',
#  'Jack Cooley',
#  'Jacob Pullen',
#  'Jacob Wiley',
#  'Jae Crowder',
#  'Jahlil Okafor',
#  'Jake Layman',
#  'Jakob Poeltl',
#  'Jalen Jones',
#  'Jamal Crawford',
#  'Jamal Murray',
#  'Jameel Warney',
#  'Jameer Nelson',
#  'Jamel Artis',
#  'James Ennis',
#  'James Harden',
#  'James Johnson',
#  'James Michael McAdoo',
#  'James Webb',
#  'James Young',
#  'Jamil Wilson',
#  'Jared Dudley',
#  'Jarell Eddie',
#  'Jarell Martin',
#  'Jarrett Allen',
#  'Jarrett Jack',
#  'Jason Smith',
#  'Jason Terry',
#  'Jawun Evans',
#  'Jaylen Brown',
#  'Jaylen Morris',
#  'Jayson Tatum',
#  'Jeff Green',
#  'Jeff Teague',
#  'Jeff Withey',
#  'Jerami Grant',
#  'Jeremy Evans',
#  'Jeremy Lamb',
#  'Jeremy Lin',
#  'Jerian Grant',
#  'Jerryd Bayless',
#  'Jimmy Butler',
#  'Joakim Noah',
#  'Jodie Meeks',
#  'Joe Harris',
#  'Joe Ingles',
#  'Joe Johnson',
#  'Joe Young',
#  'Joel Bolomboy',
#  'Joel Embiid',
#  'Joffrey Lauvergne',
#  'John Collins',
#  'John Henson',
#  'John Holland',
#  'John Wall',
#  'Johnathan Motley',
#  "Johnny O'Bryant",
#  'Jon Leuer',
#  'Jonas Jerebko',
#  'Jonas Valanciunas',
#  'Jonathan Gibson',
#  'Jonathan Isaac',
#  'Jonathon Simmons',
#  'Jordan Bell',
#  'Jordan Clarkson',
#  'Jordan Crawford',
#  'Jordan Mickey',
#  'Jose Calderon',
#  'Josh Gray',
#  'Josh Hart',
#  'Josh Huestis',
#  'Josh Jackson',
#  'Josh Magette',
#  'Josh McRoberts',
#  'Josh Richardson',
#  'Josh Smith',
#  'Jrue Holiday',
#  'Juan Hernangomez',
#  'Julius Randle',
#  'Julyan Stone',
#  'Justin Anderson',
#  'Justin Holiday',
#  'Justin Jackson',
#  'Justin Patton',
#  'Justise Winslow',
#  'Jusuf Nurkic',
#  'Kadeem Allen',
#  'Karl-Anthony Towns',
#  'Kawhi Leonard',
#  'Kay Felder',
#  'Kelly Olynyk',
#  'Kelly Oubre',
#  'Kemba Walker',
#  'Kendrick Perkins',
#  'Kenneth Faried',
#  'Kent Bazemore',
#  'Kentavious Caldwell-Pope',
#  'Kevin Durant',
#  'Kevin Love',
#  'Kevon Looney',
#  'Khem Birch',
#  'Khris Middleton',
#  'Klay Thompson',
#  'Kobi Simmons',
#  'Kosta Koufos',
#  'Kris Dunn',
#  'Kristaps Porzingis',
#  'Kyle Anderson',
#  'Kyle Collinsworth',
#  'Kyle Korver',
#  'Kyle Kuzma',
#  'Kyle Lowry',
#  "Kyle O'Quinn",
#  'Kyle Singler',
#  'Kyrie Irving',
#  'LaMarcus Aldridge',
#  'Lance Stephenson',
#  'Lance Thomas',
#  'Langston Galloway',
#  'Larry Drew',
#  'Larry Nance',
#  'Lauri Markkanen',
#  'LeBron James',
#  'London Perrantes',
#  'Lonzo Ball',
#  'Lorenzo Brown',
#  'Lou Williams',
#  'Luc Mbah a Moute',
#  'Lucas Nogueira',
#  'Luis Montero',
#  'Luke Babbitt',
#  'Luke Kennard',
#  'Luke Kornet',
#  'Luol Deng',
#  'Malachi Richardson',
#  'Malcolm Brogdon',
#  'Malcolm Delaney',
#  'Malcolm Miller',
#  'Malik Beasley',
#  'Malik Monk',
#  'Mangok Mathiang',
#  'Manu Ginobili',
#  'MarShon Brooks',
#  'Marc Gasol',
#  'Marcin Gortat',
#  'Marco Belinelli',
#  'Marcus Georges-Hunt',
#  'Marcus Morris',
#  'Marcus Paige',
#  'Marcus Smart',
#  'Mario Chalmers',
#  'Mario Hezonja',
#  'Markel Brown',
#  'Markelle Fultz',
#  'Markieff Morris',
#  'Marquese Chriss',
#  'Marquis Teague',
#  'Marreese Speights',
#  'Marshall Plumlee',
#  'Marvin Williams',
#  'Mason Plumlee',
#  'Matt Costello',
#  'Matt Williams',
#  'Matthew Dellavedova',
#  'Maurice Harkless',
#  'Maxi Kleber',
#  'Meyers Leonard',
#  'Michael Beasley',
#  'Michael Carter-Williams',
#  'Michael Kidd-Gilchrist',
#  'Mike Conley',
#  'Mike James',
#  'Mike Muscala',
#  'Mike Scott',
#  'Miles Plumlee',
#  'Milos Teodosic',
#  'Milton Doyle',
#  'Mindaugas Kuzminskas',
#  'Mirza Teletovic',
#  'Monte Morris',
#  'Montrezl Harrell',
#  'Myke Henry',
#  'Myles Turner',
#  'Nate Wolters',
#  'Naz Mitrou-Long',
#  'Nemanja Bjelica',
#  'Nene Hilario',
#  'Nerlens Noel',
#  'Nick Collison',
#  'Nick Young',
#  'Nicolas Batum',
#  'Nicolas Brussino',
#  'Nigel Hayes',
#  'Nik Stauskas',
#  'Nikola Jokic',
#  'Nikola Mirotic',
#  'Nikola Vucevic',
#  'Noah Vonleh',
#  'Norman Powell',
#  'OG Anunoby',
#  'Okaro White',
#  'Omari Johnson',
#  'Omer Asik',
#  'Omri Casspi',
#  'Otto Porter',
#  'P.J. Tucker',
#  'PJ Dozier',
#  'Pascal Siakam',
#  'Pat Connaughton',
#  'Patrick Beverley',
#  'Patrick McCaw',
#  'Patrick Patterson',
#  'Patty Mills',
#  'Pau Gasol',
#  'Paul George',
#  'Paul Millsap',
#  'Paul Zipser',
#  'Quincy Acy',
#  'Quincy Pondexter',
#  'Quinn Cook',
#  'R.J. Hunter',
#  'Rajon Rondo',
#  'Ramon Sessions',
#  'Rashad Vaughn',
#  'Raul Neto',
#  'Raymond Felton',
#  'Reggie Bullock',
#  'Reggie Hearn',
#  'Reggie Jackson',
#  'Richard Jefferson',
#  'Richaun Holmes',
#  'Ricky Rubio',
#  'Robert Covington',
#  'Robin Lopez',
#  'Rodney Hood',
#  'Rodney McGruder',
#  'Rodney Purvis',
#  'Ron Baker',
#  'Rondae Hollis-Jefferson',
#  "Royce O'Neale",
#  'Rudy Gay',
#  'Rudy Gobert',
#  'Russell Westbrook',
#  'Ryan Anderson',
#  'Ryan Arcidiacono',
#  'Salah Mejri',
#  'Sam Dekker',
#  'Scotty Hopson',
#  'Sean Kilpatrick',
#  'Semi Ojeleye',
#  'Serge Ibaka',
#  'Shabazz Muhammad',
#  'Shabazz Napier',
#  'Shane Larkin',
#  'Shaquille Harrison',
#  'Shaun Livingston',
#  'Shelvin Mack',
#  'Sindarius Thornwell',
#  'Skal Labissiere',
#  'Solomon Hill',
#  'Spencer Dinwiddie',
#  'Stanley Johnson',
#  'Stephen Curry',
#  'Sterling Brown',
#  'Steven Adams',
#  'T.J. Leaf',
#  'T.J. McConnell',
#  'T.J. Warren',
#  'Taj Gibson',
#  'Tarik Black',
#  'Taurean Waller-Prince',
#  'Terrance Ferguson',
#  'Terrence Ross',
#  'Terry Rozier',
#  'Thabo Sefolosha',
#  'Thaddeus Young',
#  'Thomas Bryant',
#  'Thon Maker',
#  'Tim Frazier',
#  'Tim Hardaway',
#  'Tim Quarterman',
#  'Timofey Mozgov',
#  'Timothe Luwawu-Cabarrot',
#  'Tobias Harris',
#  'Tomas Satoransky',
#  'Tony Allen',
#  'Tony Bradley',
#  'Tony Parker',
#  'Tony Snell',
#  'Torrey Craig',
#  'Travis Wear',
#  'Treveon Graham',
#  'Trevor Ariza',
#  'Trevor Booker',
#  'Trey Burke',
#  'Trey Lyles',
#  'Trey McKinney-Jones',
#  'Tristan Thompson',
#  'Troy Daniels',
#  'Troy Williams',
#  'Tyler Cavanaugh',
#  'Tyler Dorsey',
#  'Tyler Ennis',
#  'Tyler Johnson',
#  'Tyler Lydon',
#  'Tyler Ulis',
#  'Tyler Zeller',
#  'Tyreke Evans',
#  'Tyrone Wallace',
#  'Tyson Chandler',
#  'Tyus Jones',
#  'Udonis Haslem',
#  'Vander Blue',
#  'Victor Oladipo',
#  'Vince Carter',
#  'Vince Hunter',
#  'Wade Baldwin',
#  'Walt Lemon Jr.',
#  'Wayne Ellington',
#  'Wayne Selden',
#  'Wesley Iwundu',
#  'Wesley Johnson',
#  'Wesley Matthews',
#  'Will Barton',
#  'Willie Cauley-Stein',
#  'Willie Reed',
#  'Willy Hernangomez',
#  'Wilson Chandler',
#  'Xavier Munford',
#  'Xavier Rathan-Mayes',
#  'Xavier Silas',
#  'Yogi Ferrell',
#  'Zach Collins',
#  'Zach LaVine',
#  'Zach Randolph',
#  'Zaza Pachulia',
#  'Zhou Qi']

# %%
clean_list = {}
for name in player_list:
    inputname=name
    name=name.replace("Luc Mbah a Moute","LucRichardMbahAMoute")
    name=name.replace("Luc Richard Mbah a Moute","LucRichardMbahAMoute")
    name=name.replace("Nazareth","Naz")
    name=name.replace("Raulzinho","Raul")
    name=name.replace("James Webb III","James Webb")
    name=name.replace("James Web III","James Webb")
    name=name.replace("Juancho","Juan")
    name=name.replace("Patty Mills","Patrick Mills")
    name=name.replace("J.J. Barea","Jose Barea")
    name=name.replace("Ish Smith","Ishmael Smith")
    name=name.replace("Poeltl","Poltl")
    name=name.replace("Vincent Hunter","Vince Hunter")
    name=name.replace("Joe Young","Joseph Young")
    name=name.replace("Maurice Harkless","Moe Harkless")
    name=name.replace("Wes Iwundu","Wesley Iwundu")
    name=name.replace("Wesley Johnson","Wes Johnson")
    name=name.replace("Taurean Waller-Prince","Taurean Prince")
    for x in "ÀÁÂÃÄÅĀ":
        name=name.replace(x,"A");
    for x in "àáâãäåā":
        name=name.replace(x,"a");
    for x in "ëèéê":
        name=name.replace(x,"e");
    for x in "ôóøŏöò":
        name=name.replace(x,"o");
    for x in "úùüū":
        name=name.replace(x,"u");
        
    name=name.replace("ģ","g")
    name=name.replace("č","c")
    name=name.replace("ć","c")
    name=name.replace("š","s")
    name=name.replace("ņ","n")
    name=name.replace("ñ","n")
    name=name.replace("í","i")
    name=name.replace("Ž","Z")
    name=name.replace("ž","z")
    name=name.replace("ý","y")
    name=name.replace("'","")
    name=name.replace("’","")
    name=name.replace(".","")
    name=name.replace(" Jr","")
    name=name.replace("IV","")
    name=name.replace("III","")
    name=name.replace("II","")
    name=name.replace("-","")
    name=name.replace(",","")
    name=name.replace(" ","")
    name=name.replace("*","")
    
    clean_list[inputname] = name

# %%
clean_list
# Out:
# {'Aaron Brooks': 'AaronBrooks',
#  'Aaron Gordon': 'AaronGordon',
#  'Aaron Harrison': 'AaronHarrison',
#  'Aaron Jackson': 'AaronJackson',
#  'Abdel Nader': 'AbdelNader',
#  'Adreian Payne': 'AdreianPayne',
#  'Al Horford': 'AlHorford',
#  'Al Jefferson': 'AlJefferson',
#  'Al-Farouq Aminu': 'AlFarouqAminu',
#  'Alan Williams': 'AlanWilliams',
#  'Alec Burks': 'AlecBurks',
#  'Alec Peters': 'AlecPeters',
#  'Alex Abrines': 'AlexAbrines',
#  'Alex Caruso': 'AlexCaruso',
#  'Alex Len': 'AlexLen',
#  'Alex Poythress': 'AlexPoythress',
#  'Alfonzo McKinnie': 'AlfonzoMcKinnie',
#  'Allen Crabbe': 'AllenCrabbe',
#  'Amir Johnson': 'AmirJohnson',
#  'Andre Drummond': 'AndreDrummond',
#  'Andre Iguodala': 'AndreIguodala',
#  'Andre Ingram': 'AndreIngram',
#  'Andre Roberson': 'AndreRoberson',
#  'Andrew Bogut': 'AndrewBogut',
#  'Andrew Harrison': 'AndrewHarrison',
#  'Andrew White': 'AndrewWhite',
#  'Andrew Wiggins': 'AndrewWiggins',
#  'Ante Zizic': 'AnteZizic',
#  'Anthony Brown': 'AnthonyBrown',
#  'Anthony Davis': 'AnthonyDavis',
#  'Anthony Tolliver': 'AnthonyTolliver',
#  'Antonio Blakeney': 'AntonioBlakeney',
#  'Antonius Cleveland': 'AntoniusCleveland',
#  'Aron Baynes': 'AronBaynes',
#  'Arron Afflalo': 'ArronAfflalo',
#  'Austin Rivers': 'AustinRivers',
#  'Avery Bradley': 'AveryBradley',
#  'Bam Adebayo': 'BamAdebayo',
#  'Ben McLemore': 'BenMcLemore',
#  'Ben Moore': 'BenMoore',
#  'Ben Simmons': 'BenSimmons',
#  'Bismack Biyombo': 'BismackBiyombo',
#  'Blake Griffin': 'BlakeGriffin',
#  'Boban Marjanovic': 'BobanMarjanovic',
#  'Bobby Brown': 'BobbyBrown',
#  'Bobby Portis': 'BobbyPortis',
#  'Bogdan Bogdanovic': 'BogdanBogdanovic',
#  'Bojan Bogdanovic': 'BojanBogdanovic',
#  'Bradley Beal': 'BradleyBeal',
#  'Brandan Wright': 'BrandanWright',
#  'Brandon Ingram': 'BrandonIngram',
#  'Brandon Jennings': 'BrandonJennings',
#  'Brandon Paul': 'BrandonPaul',
#  'Briante Weber': 'BrianteWeber',
#  'Brice Johnson': 'BriceJohnson',
#  'Brook Lopez': 'BrookLopez',
#  'Bruno Caboclo': 'BrunoCaboclo',
#  'Bryn Forbes': 'BrynForbes',
#  'Buddy Hield': 'BuddyHield',
#  'C.J. Miles': 'CJMiles',
#  'C.J. Williams': 'CJWilliams',
#  'CJ McCollum': 'CJMcCollum',
#  'Caleb Swanigan': 'CalebSwanigan',
#  'Cameron Payne': 'CameronPayne',
#  'Caris LeVert': 'CarisLeVert',
#  'Carmelo Anthony': 'CarmeloAnthony',
#  'Cedi Osman': 'CediOsman',
#  'Chandler Parsons': 'ChandlerParsons',
#  'Channing Frye': 'ChanningFrye',
#  'Charles Cooke': 'CharlesCooke',
#  'Cheick Diallo': 'CheickDiallo',
#  'Chinanu Onuaku': 'ChinanuOnuaku',
#  'Chris Boucher': 'ChrisBoucher',
#  'Chris McCullough': 'ChrisMcCullough',
#  'Chris Paul': 'ChrisPaul',
#  'Clint Capela': 'ClintCapela',
#  'Cody Zeller': 'CodyZeller',
#  'Cole Aldrich': 'ColeAldrich',
#  'Corey Brewer': 'CoreyBrewer',
#  'Cory Joseph': 'CoryJoseph',
#  'Courtney Lee': 'CourtneyLee',
#  'Cristiano Felicio': 'CristianoFelicio',
#  "D'Angelo Russell": 'DAngeloRussell',
#  'D.J. Augustin': 'DJAugustin',
#  'D.J. Wilson': 'DJWilson',
#  'Dakari Johnson': 'DakariJohnson',
#  'Damian Jones': 'DamianJones',
#  'Damian Lillard': 'DamianLillard',
#  'Damien Wilkins': 'DamienWilkins',
#  'Damion Lee': 'DamionLee',
#  'Damyean Dotson': 'DamyeanDotson',
#  'Daniel Hamilton': 'DanielHamilton',
#  'Daniel Theis': 'DanielTheis',
#  'Danilo Gallinari': 'DaniloGallinari',
#  'Danny Green': 'DannyGreen',
#  'Dante Cunningham': 'DanteCunningham',
#  'Dante Exum': 'DanteExum',
#  'Danuel House': 'DanuelHouse',
#  'Dario Saric': 'DarioSaric',
#  'Darius Miller': 'DariusMiller',
#  'Darrell Arthur': 'DarrellArthur',
#  'Darren Collison': 'DarrenCollison',
#  'Darrun Hilliard': 'DarrunHilliard',
#  'David Nwaba': 'DavidNwaba',
#  'David Stockton': 'DavidStockton',
#  'David West': 'DavidWest',
#  'Davis Bertans': 'DavisBertans',
#  'Davon Reed': 'DavonReed',
#  "De'Aaron Fox": 'DeAaronFox',
#  'DeAndre Jordan': 'DeAndreJordan',
#  'DeAndre Liggins': 'DeAndreLiggins',
#  "DeAndre' Bembry": 'DeAndreBembry',
#  'DeMar DeRozan': 'DeMarDeRozan',
#  'DeMarcus Cousins': 'DeMarcusCousins',
#  'DeMarre Carroll': 'DeMarreCarroll',
#  'Dejounte Murray': 'DejounteMurray',
#  'Delon Wright': 'DelonWright',
#  'Demetrius Jackson': 'DemetriusJackson',
#  'Dennis Schroder': 'DennisSchroder',
#  'Dennis Smith': 'DennisSmith',
#  'Denzel Valentine': 'DenzelValentine',
#  'Derrick Favors': 'DerrickFavors',
#  'Derrick Jones': 'DerrickJones',
#  'Derrick Rose': 'DerrickRose',
#  'Derrick Walton': 'DerrickWalton',
#  'Derrick White': 'DerrickWhite',
#  'Derrick Williams': 'DerrickWilliams',
#  'Devin Booker': 'DevinBooker',
#  'Devin Harris': 'DevinHarris',
#  'Devin Robinson': 'DevinRobinson',
#  'Dewayne Dedmon': 'DewayneDedmon',
#  'Deyonta Davis': 'DeyontaDavis',
#  'Dillon Brooks': 'DillonBrooks',
#  'Dion Waiters': 'DionWaiters',
#  'Dirk Nowitzki': 'DirkNowitzki',
#  'Domantas Sabonis': 'DomantasSabonis',
#  'Donovan Mitchell': 'DonovanMitchell',
#  'Dorian Finney-Smith': 'DorianFinneySmith',
#  'Doug McDermott': 'DougMcDermott',
#  'Dragan Bender': 'DraganBender',
#  'Draymond Green': 'DraymondGreen',
#  'Dwayne Bacon': 'DwayneBacon',
#  'Dwight Buycks': 'DwightBuycks',
#  'Dwight Howard': 'DwightHoward',
#  'Dwight Powell': 'DwightPowell',
#  'Dwyane Wade': 'DwyaneWade',
#  "E'Twaun Moore": 'ETwaunMoore',
#  'Ed Davis': 'EdDavis',
#  'Edmond Sumner': 'EdmondSumner',
#  'Ekpe Udoh': 'EkpeUdoh',
#  'Elfrid Payton': 'ElfridPayton',
#  'Emeka Okafor': 'EmekaOkafor',
#  'Emmanuel Mudiay': 'EmmanuelMudiay',
#  'Enes Kanter': 'EnesKanter',
#  'Eric Bledsoe': 'EricBledsoe',
#  'Eric Gordon': 'EricGordon',
#  'Eric Moreland': 'EricMoreland',
#  'Erik McCree': 'ErikMcCree',
#  'Ersan Ilyasova': 'ErsanIlyasova',
#  'Evan Fournier': 'EvanFournier',
#  'Evan Turner': 'EvanTurner',
#  'Frank Kaminsky': 'FrankKaminsky',
#  'Frank Mason': 'FrankMason',
#  'Frank Ntilikina': 'FrankNtilikina',
#  'Fred VanVleet': 'FredVanVleet',
#  'Furkan Korkmaz': 'FurkanKorkmaz',
#  'Garrett Temple': 'GarrettTemple',
#  'Gary Harris': 'GaryHarris',
#  'Gary Payton': 'GaryPayton',
#  'George Hill': 'GeorgeHill',
#  'Georges Niang': 'GeorgesNiang',
#  'Georgios Papagiannis': 'GeorgiosPapagiannis',
#  'Gerald Green': 'GeraldGreen',
#  'Gian Clavell': 'GianClavell',
#  'Giannis Antetokounmpo': 'GiannisAntetokounmpo',
#  'Glenn Robinson': 'GlennRobinson',
#  'Goran Dragic': 'GoranDragic',
#  'Gordon Hayward': 'GordonHayward',
#  'Gorgui Dieng': 'GorguiDieng',
#  'Greg Monroe': 'GregMonroe',
#  'Guerschon Yabusele': 'GuerschonYabusele',
#  'Harrison Barnes': 'HarrisonBarnes',
#  'Hassan Whiteside': 'HassanWhiteside',
#  'Henry Ellenson': 'HenryEllenson',
#  'Ian Clark': 'IanClark',
#  'Ian Mahinmi': 'IanMahinmi',
#  'Ike Anigbogu': 'IkeAnigbogu',
#  'Iman Shumpert': 'ImanShumpert',
#  'Isaiah Canaan': 'IsaiahCanaan',
#  'Isaiah Hicks': 'IsaiahHicks',
#  'Isaiah Taylor': 'IsaiahTaylor',
#  'Isaiah Thomas': 'IsaiahThomas',
#  'Isaiah Whitehead': 'IsaiahWhitehead',
#  'Ish Smith': 'IshmaelSmith',
#  'Ivan Rabb': 'IvanRabb',
#  'Ivica Zubac': 'IvicaZubac',
#  'J.J. Barea': 'JoseBarea',
#  'J.J. Redick': 'JJRedick',
#  'J.R. Smith': 'JRSmith',
#  'JaKarr Sampson': 'JaKarrSampson',
#  'JaMychal Green': 'JaMychalGreen',
#  'JaVale McGee': 'JaValeMcGee',
#  'Jabari Bird': 'JabariBird',
#  'Jabari Parker': 'JabariParker',
#  'Jack Cooley': 'JackCooley',
#  'Jacob Pullen': 'JacobPullen',
#  'Jacob Wiley': 'JacobWiley',
#  'Jae Crowder': 'JaeCrowder',
#  'Jahlil Okafor': 'JahlilOkafor',
#  'Jake Layman': 'JakeLayman',
#  'Jakob Poeltl': 'JakobPoltl',
#  'Jalen Jones': 'JalenJones',
#  'Jamal Crawford': 'JamalCrawford',
#  'Jamal Murray': 'JamalMurray',
#  'Jameel Warney': 'JameelWarney',
#  'Jameer Nelson': 'JameerNelson',
#  'Jamel Artis': 'JamelArtis',
#  'James Ennis': 'JamesEnnis',
#  'James Harden': 'JamesHarden',
#  'James Johnson': 'JamesJohnson',
#  'James Michael McAdoo': 'JamesMichaelMcAdoo',
#  'James Webb': 'JamesWebb',
#  'James Young': 'JamesYoung',
#  'Jamil Wilson': 'JamilWilson',
#  'Jared Dudley': 'JaredDudley',
#  'Jarell Eddie': 'JarellEddie',
#  'Jarell Martin': 'JarellMartin',
#  'Jarrett Allen': 'JarrettAllen',
#  'Jarrett Jack': 'JarrettJack',
#  'Jason Smith': 'JasonSmith',
#  'Jason Terry': 'JasonTerry',
#  'Jawun Evans': 'JawunEvans',
#  'Jaylen Brown': 'JaylenBrown',
#  'Jaylen Morris': 'JaylenMorris',
#  'Jayson Tatum': 'JaysonTatum',
#  'Jeff Green': 'JeffGreen',
#  'Jeff Teague': 'JeffTeague',
#  'Jeff Withey': 'JeffWithey',
#  'Jerami Grant': 'JeramiGrant',
#  'Jeremy Evans': 'JeremyEvans',
#  'Jeremy Lamb': 'JeremyLamb',
#  'Jeremy Lin': 'JeremyLin',
#  'Jerian Grant': 'JerianGrant',
#  'Jerryd Bayless': 'JerrydBayless',
#  'Jimmy Butler': 'JimmyButler',
#  'Joakim Noah': 'JoakimNoah',
#  'Jodie Meeks': 'JodieMeeks',
#  'Joe Harris': 'JoeHarris',
#  'Joe Ingles': 'JoeIngles',
#  'Joe Johnson': 'JoeJohnson',
#  'Joe Young': 'JosephYoung',
#  'Joel Bolomboy': 'JoelBolomboy',
#  'Joel Embiid': 'JoelEmbiid',
#  'Joffrey Lauvergne': 'JoffreyLauvergne',
#  'John Collins': 'JohnCollins',
#  'John Henson': 'JohnHenson',
#  'John Holland': 'JohnHolland',
#  'John Wall': 'JohnWall',
#  'Johnathan Motley': 'JohnathanMotley',
#  "Johnny O'Bryant": 'JohnnyOBryant',
#  'Jon Leuer': 'JonLeuer',
#  'Jonas Jerebko': 'JonasJerebko',
#  'Jonas Valanciunas': 'JonasValanciunas',
#  'Jonathan Gibson': 'JonathanGibson',
#  'Jonathan Isaac': 'JonathanIsaac',
#  'Jonathon Simmons': 'JonathonSimmons',
#  'Jordan Bell': 'JordanBell',
#  'Jordan Clarkson': 'JordanClarkson',
#  'Jordan Crawford': 'JordanCrawford',
#  'Jordan Mickey': 'JordanMickey',
#  'Jose Calderon': 'JoseCalderon',
#  'Josh Gray': 'JoshGray',
#  'Josh Hart': 'JoshHart',
#  'Josh Huestis': 'JoshHuestis',
#  'Josh Jackson': 'JoshJackson',
#  'Josh Magette': 'JoshMagette',
#  'Josh McRoberts': 'JoshMcRoberts',
#  'Josh Richardson': 'JoshRichardson',
#  'Josh Smith': 'JoshSmith',
#  'Jrue Holiday': 'JrueHoliday',
#  'Juan Hernangomez': 'JuanHernangomez',
#  'Julius Randle': 'JuliusRandle',
#  'Julyan Stone': 'JulyanStone',
#  'Justin Anderson': 'JustinAnderson',
#  'Justin Holiday': 'JustinHoliday',
#  'Justin Jackson': 'JustinJackson',
#  'Justin Patton': 'JustinPatton',
#  'Justise Winslow': 'JustiseWinslow',
#  'Jusuf Nurkic': 'JusufNurkic',
#  'Kadeem Allen': 'KadeemAllen',
#  'Karl-Anthony Towns': 'KarlAnthonyTowns',
#  'Kawhi Leonard': 'KawhiLeonard',
#  'Kay Felder': 'KayFelder',
#  'Kelly Olynyk': 'KellyOlynyk',
#  'Kelly Oubre': 'KellyOubre',
#  'Kemba Walker': 'KembaWalker',
#  'Kendrick Perkins': 'KendrickPerkins',
#  'Kenneth Faried': 'KennethFaried',
#  'Kent Bazemore': 'KentBazemore',
#  'Kentavious Caldwell-Pope': 'KentaviousCaldwellPope',
#  'Kevin Durant': 'KevinDurant',
#  'Kevin Love': 'KevinLove',
#  'Kevon Looney': 'KevonLooney',
#  'Khem Birch': 'KhemBirch',
#  'Khris Middleton': 'KhrisMiddleton',
#  'Klay Thompson': 'KlayThompson',
#  'Kobi Simmons': 'KobiSimmons',
#  'Kosta Koufos': 'KostaKoufos',
#  'Kris Dunn': 'KrisDunn',
#  'Kristaps Porzingis': 'KristapsPorzingis',
#  'Kyle Anderson': 'KyleAnderson',
#  'Kyle Collinsworth': 'KyleCollinsworth',
#  'Kyle Korver': 'KyleKorver',
#  'Kyle Kuzma': 'KyleKuzma',
#  'Kyle Lowry': 'KyleLowry',
#  "Kyle O'Quinn": 'KyleOQuinn',
#  'Kyle Singler': 'KyleSingler',
#  'Kyrie Irving': 'KyrieIrving',
#  'LaMarcus Aldridge': 'LaMarcusAldridge',
#  'Lance Stephenson': 'LanceStephenson',
#  'Lance Thomas': 'LanceThomas',
#  'Langston Galloway': 'LangstonGalloway',
#  'Larry Drew': 'LarryDrew',
#  'Larry Nance': 'LarryNance',
#  'Lauri Markkanen': 'LauriMarkkanen',
#  'LeBron James': 'LeBronJames',
#  'London Perrantes': 'LondonPerrantes',
#  'Lonzo Ball': 'LonzoBall',
#  'Lorenzo Brown': 'LorenzoBrown',
#  'Lou Williams': 'LouWilliams',
#  'Luc Mbah a Moute': 'LucRichardMbahAMoute',
#  'Lucas Nogueira': 'LucasNogueira',
#  'Luis Montero': 'LuisMontero',
#  'Luke Babbitt': 'LukeBabbitt',
#  'Luke Kennard': 'LukeKennard',
#  'Luke Kornet': 'LukeKornet',
#  'Luol Deng': 'LuolDeng',
#  'Malachi Richardson': 'MalachiRichardson',
#  'Malcolm Brogdon': 'MalcolmBrogdon',
#  'Malcolm Delaney': 'MalcolmDelaney',
#  'Malcolm Miller': 'MalcolmMiller',
#  'Malik Beasley': 'MalikBeasley',
#  'Malik Monk': 'MalikMonk',
#  'Mangok Mathiang': 'MangokMathiang',
#  'Manu Ginobili': 'ManuGinobili',
#  'MarShon Brooks': 'MarShonBrooks',
#  'Marc Gasol': 'MarcGasol',
#  'Marcin Gortat': 'MarcinGortat',
#  'Marco Belinelli': 'MarcoBelinelli',
#  'Marcus Georges-Hunt': 'MarcusGeorgesHunt',
#  'Marcus Morris': 'MarcusMorris',
#  'Marcus Paige': 'MarcusPaige',
#  'Marcus Smart': 'MarcusSmart',
#  'Mario Chalmers': 'MarioChalmers',
#  'Mario Hezonja': 'MarioHezonja',
#  'Markel Brown': 'MarkelBrown',
#  'Markelle Fultz': 'MarkelleFultz',
#  'Markieff Morris': 'MarkieffMorris',
#  'Marquese Chriss': 'MarqueseChriss',
#  'Marquis Teague': 'MarquisTeague',
#  'Marreese Speights': 'MarreeseSpeights',
#  'Marshall Plumlee': 'MarshallPlumlee',
#  'Marvin Williams': 'MarvinWilliams',
#  'Mason Plumlee': 'MasonPlumlee',
#  'Matt Costello': 'MattCostello',
#  'Matt Williams': 'MattWilliams',
#  'Matthew Dellavedova': 'MatthewDellavedova',
#  'Maurice Harkless': 'MoeHarkless',
#  'Maxi Kleber': 'MaxiKleber',
#  'Meyers Leonard': 'MeyersLeonard',
#  'Michael Beasley': 'MichaelBeasley',
#  'Michael Carter-Williams': 'MichaelCarterWilliams',
#  'Michael Kidd-Gilchrist': 'MichaelKiddGilchrist',
#  'Mike Conley': 'MikeConley',
#  'Mike James': 'MikeJames',
#  'Mike Muscala': 'MikeMuscala',
#  'Mike Scott': 'MikeScott',
#  'Miles Plumlee': 'MilesPlumlee',
#  'Milos Teodosic': 'MilosTeodosic',
#  'Milton Doyle': 'MiltonDoyle',
#  'Mindaugas Kuzminskas': 'MindaugasKuzminskas',
#  'Mirza Teletovic': 'MirzaTeletovic',
#  'Monte Morris': 'MonteMorris',
#  'Montrezl Harrell': 'MontrezlHarrell',
#  'Myke Henry': 'MykeHenry',
#  'Myles Turner': 'MylesTurner',
#  'Nate Wolters': 'NateWolters',
#  'Naz Mitrou-Long': 'NazMitrouLong',
#  'Nemanja Bjelica': 'NemanjaBjelica',
#  'Nene Hilario': 'NeneHilario',
#  'Nerlens Noel': 'NerlensNoel',
#  'Nick Collison': 'NickCollison',
#  'Nick Young': 'NickYoung',
#  'Nicolas Batum': 'NicolasBatum',
#  'Nicolas Brussino': 'NicolasBrussino',
#  'Nigel Hayes': 'NigelHayes',
#  'Nik Stauskas': 'NikStauskas',
#  'Nikola Jokic': 'NikolaJokic',
#  'Nikola Mirotic': 'NikolaMirotic',
#  'Nikola Vucevic': 'NikolaVucevic',
#  'Noah Vonleh': 'NoahVonleh',
#  'Norman Powell': 'NormanPowell',
#  'OG Anunoby': 'OGAnunoby',
#  'Okaro White': 'OkaroWhite',
#  'Omari Johnson': 'OmariJohnson',
#  'Omer Asik': 'OmerAsik',
#  'Omri Casspi': 'OmriCasspi',
#  'Otto Porter': 'OttoPorter',
#  'P.J. Tucker': 'PJTucker',
#  'PJ Dozier': 'PJDozier',
#  'Pascal Siakam': 'PascalSiakam',
#  'Pat Connaughton': 'PatConnaughton',
#  'Patrick Beverley': 'PatrickBeverley',
#  'Patrick McCaw': 'PatrickMcCaw',
#  'Patrick Patterson': 'PatrickPatterson',
#  'Patty Mills': 'PatrickMills',
#  'Pau Gasol': 'PauGasol',
#  'Paul George': 'PaulGeorge',
#  'Paul Millsap': 'PaulMillsap',
#  'Paul Zipser': 'PaulZipser',
#  'Quincy Acy': 'QuincyAcy',
#  'Quincy Pondexter': 'QuincyPondexter',
#  'Quinn Cook': 'QuinnCook',
#  'R.J. Hunter': 'RJHunter',
#  'Rajon Rondo': 'RajonRondo',
#  'Ramon Sessions': 'RamonSessions',
#  'Rashad Vaughn': 'RashadVaughn',
#  'Raul Neto': 'RaulNeto',
#  'Raymond Felton': 'RaymondFelton',
#  'Reggie Bullock': 'ReggieBullock',
#  'Reggie Hearn': 'ReggieHearn',
#  'Reggie Jackson': 'ReggieJackson',
#  'Richard Jefferson': 'RichardJefferson',
#  'Richaun Holmes': 'RichaunHolmes',
#  'Ricky Rubio': 'RickyRubio',
#  'Robert Covington': 'RobertCovington',
#  'Robin Lopez': 'RobinLopez',
#  'Rodney Hood': 'RodneyHood',
#  'Rodney McGruder': 'RodneyMcGruder',
#  'Rodney Purvis': 'RodneyPurvis',
#  'Ron Baker': 'RonBaker',
#  'Rondae Hollis-Jefferson': 'RondaeHollisJefferson',
#  "Royce O'Neale": 'RoyceONeale',
#  'Rudy Gay': 'RudyGay',
#  'Rudy Gobert': 'RudyGobert',
#  'Russell Westbrook': 'RussellWestbrook',
#  'Ryan Anderson': 'RyanAnderson',
#  'Ryan Arcidiacono': 'RyanArcidiacono',
#  'Salah Mejri': 'SalahMejri',
#  'Sam Dekker': 'SamDekker',
#  'Scotty Hopson': 'ScottyHopson',
#  'Sean Kilpatrick': 'SeanKilpatrick',
#  'Semi Ojeleye': 'SemiOjeleye',
#  'Serge Ibaka': 'SergeIbaka',
#  'Shabazz Muhammad': 'ShabazzMuhammad',
#  'Shabazz Napier': 'ShabazzNapier',
#  'Shane Larkin': 'ShaneLarkin',
#  'Shaquille Harrison': 'ShaquilleHarrison',
#  'Shaun Livingston': 'ShaunLivingston',
#  'Shelvin Mack': 'ShelvinMack',
#  'Sindarius Thornwell': 'SindariusThornwell',
#  'Skal Labissiere': 'SkalLabissiere',
#  'Solomon Hill': 'SolomonHill',
#  'Spencer Dinwiddie': 'SpencerDinwiddie',
#  'Stanley Johnson': 'StanleyJohnson',
#  'Stephen Curry': 'StephenCurry',
#  'Sterling Brown': 'SterlingBrown',
#  'Steven Adams': 'StevenAdams',
#  'T.J. Leaf': 'TJLeaf',
#  'T.J. McConnell': 'TJMcConnell',
#  'T.J. Warren': 'TJWarren',
#  'Taj Gibson': 'TajGibson',
#  'Tarik Black': 'TarikBlack',
#  'Taurean Waller-Prince': 'TaureanPrince',
#  'Terrance Ferguson': 'TerranceFerguson',
#  'Terrence Ross': 'TerrenceRoss',
#  'Terry Rozier': 'TerryRozier',
#  'Thabo Sefolosha': 'ThaboSefolosha',
#  'Thaddeus Young': 'ThaddeusYoung',
#  'Thomas Bryant': 'ThomasBryant',
#  'Thon Maker': 'ThonMaker',
#  'Tim Frazier': 'TimFrazier',
#  'Tim Hardaway': 'TimHardaway',
#  'Tim Quarterman': 'TimQuarterman',
#  'Timofey Mozgov': 'TimofeyMozgov',
#  'Timothe Luwawu-Cabarrot': 'TimotheLuwawuCabarrot',
#  'Tobias Harris': 'TobiasHarris',
#  'Tomas Satoransky': 'TomasSatoransky',
#  'Tony Allen': 'TonyAllen',
#  'Tony Bradley': 'TonyBradley',
#  'Tony Parker': 'TonyParker',
#  'Tony Snell': 'TonySnell',
#  'Torrey Craig': 'TorreyCraig',
#  'Travis Wear': 'TravisWear',
#  'Treveon Graham': 'TreveonGraham',
#  'Trevor Ariza': 'TrevorAriza',
#  'Trevor Booker': 'TrevorBooker',
#  'Trey Burke': 'TreyBurke',
#  'Trey Lyles': 'TreyLyles',
#  'Trey McKinney-Jones': 'TreyMcKinneyJones',
#  'Tristan Thompson': 'TristanThompson',
#  'Troy Daniels': 'TroyDaniels',
#  'Troy Williams': 'TroyWilliams',
#  'Tyler Cavanaugh': 'TylerCavanaugh',
#  'Tyler Dorsey': 'TylerDorsey',
#  'Tyler Ennis': 'TylerEnnis',
#  'Tyler Johnson': 'TylerJohnson',
#  'Tyler Lydon': 'TylerLydon',
#  'Tyler Ulis': 'TylerUlis',
#  'Tyler Zeller': 'TylerZeller',
#  'Tyreke Evans': 'TyrekeEvans',
#  'Tyrone Wallace': 'TyroneWallace',
#  'Tyson Chandler': 'TysonChandler',
#  'Tyus Jones': 'TyusJones',
#  'Udonis Haslem': 'UdonisHaslem',
#  'Vander Blue': 'VanderBlue',
#  'Victor Oladipo': 'VictorOladipo',
#  'Vince Carter': 'VinceCarter',
#  'Vince Hunter': 'VinceHunter',
#  'Wade Baldwin': 'WadeBaldwin',
#  'Walt Lemon Jr.': 'WaltLemon',
#  'Wayne Ellington': 'WayneEllington',
#  'Wayne Selden': 'WayneSelden',
#  'Wesley Iwundu': 'WesleyIwundu',
#  'Wesley Johnson': 'WesJohnson',
#  'Wesley Matthews': 'WesleyMatthews',
#  'Will Barton': 'WillBarton',
#  'Willie Cauley-Stein': 'WillieCauleyStein',
#  'Willie Reed': 'WillieReed',
#  'Willy Hernangomez': 'WillyHernangomez',
#  'Wilson Chandler': 'WilsonChandler',
#  'Xavier Munford': 'XavierMunford',
#  'Xavier Rathan-Mayes': 'XavierRathanMayes',
#  'Xavier Silas': 'XavierSilas',
#  'Yogi Ferrell': 'YogiFerrell',
#  'Zach Collins': 'ZachCollins',
#  'Zach LaVine': 'ZachLaVine',
#  'Zach Randolph': 'ZachRandolph',
#  'Zaza Pachulia': 'ZazaPachulia',
#  'Zhou Qi': 'ZhouQi'}

# %%
the_df["formatname"] = the_df["format_name"].astype(str).map(clean_list)
the_df.drop(columns=["GS"],inplace=True)
the_df.to_csv("data/2018_stats.csv",encoding="utf-8")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
past_totals.dtypes
# Out:
# Unnamed: 0      int64
# Year          float64
# Player         object
# Pos            object
# Age           float64
# Tm             object
# G             float64
# MP            float64
# PER           float64
# TS%           float64
# 3PAr          float64
# FTr           float64
# ORB%          float64
# DRB%          float64
# TRB%          float64
# AST%          float64
# STL%          float64
# BLK%          float64
# TOV%          float64
# USG%          float64
# OWS           float64
# DWS           float64
# WS            float64
# WS/48         float64
# OBPM          float64
# DBPM          float64
# BPM           float64
# VORP          float64
# FG            float64
# FGA           float64
# FG%           float64
# 3P            float64
# 3PA           float64
# 3P%           float64
# 2P            float64
# 2PA           float64
# 2P%           float64
# eFG%          float64
# FT            float64
# FTA           float64
# FT%           float64
# ORB           float64
# DRB           float64
# TRB           float64
# AST           float64
# STL           float64
# BLK           float64
# TOV           float64
# PF            float64
# PTS           float64
# formatname     object
# dtype: object
